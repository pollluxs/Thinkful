# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
powers = pd.read_csv('Data/superheroes_power_matrix.csv')
stats = pd.read_csv('Data/charcters_stats.csv')
marvel_characters_info = pd.read_csv('Data/marvel_characters_info.csv')
marvel_DC_characters = pd.read_excel('Data/marvel_dc_characters.xlsx')

# %%
powers_df = pd.DataFrame(powers)
stats_df = pd.DataFrame(stats)
marvel_chars_info_df = pd.DataFrame(marvel_characters_info)
marvel_DC_char_df = pd.DataFrame(marvel_DC_characters)

# %%
powers_df.head()
# Out:
#           Name  Agility  Accelerated Healing  Lantern Power Ring  \
# 0      3-D Man     True                False               False
# 1       A-Bomb    False                 True               False
# 2   Abe Sapien     True                 True               False
# 3     Abin Sur    False                False                True
# 4  Abomination    False                 True               False
#
#    Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 0                  False            False       False    False
# 1                  False            False        True    False
# 2                  False             True        True    False
# 3                  False            False       False    False
# 4                  False            False       False    False
#
#    Energy Absorption  Flight     ...      Web Creation  Reality Warping  \
# 0              False   False     ...             False            False
# ...

# %%
stats_df.Total.max()
# Out:
# 581

# %%
stats_df[stats_df['Total']>=530]
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 16               Amazo       bad            75       100    100         100
# 82             Bizarro   neutral            75        95    100         100
# 171    Cyborg Superman       bad            75        93     92         100
# 201           Doomsday       bad            88        80     67         120
# 203           Dormammu       bad            88        95     83         100
# 219              Faora       bad            88        95     75         100
# 238           Galactus   neutral           100       100     83         100
# 242        General Zod       bad            94       100     96         100
# 356              Magus       bad            88       100     70          99
# 361  Martian Manhunter      good           100       100     96         100
# 417               Nova      good           100        85     67         101
# ...

# %%
stats_df.head()
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 4  Abomination       bad            63        80     53          90     55
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 4      95    436

# %%
marvel_chars_info_df.head(25)
# Out:
#     ID               Name Alignment  Gender EyeColor               Race  \
# 0    0             A-Bomb      good    Male   yellow              Human
# 1    1         Abe Sapien      good    Male     blue      Icthyo Sapien
# 2    2           Abin Sur      good    Male     blue            Ungaran
# 3    3        Abomination       bad    Male    green  Human / Radiation
# 4    4            Abraxas       bad    Male     blue      Cosmic Entity
# 5    5      Absorbing Man       bad    Male     blue              Human
# 6    6        Adam Monroe      good    Male     blue                  -
# 7    7       Adam Strange      good    Male     blue              Human
# 8    8           Agent 13      good  Female     blue                  -
# 9    9          Agent Bob      good    Male    brown              Human
# 10  10         Agent Zero      good    Male        -                  -
# 11  11         Air-Walker       bad    Male     blue                  -
# ...

# %%
stats_df.max()
# Out:
# Name            Zoom
# Intelligence     113
# Strength         100
# Speed            100
# Durability       120
# Power            100
# Combat           101
# Total            581
# dtype: object

# %%
good = pd.DataFrame(stats_df[stats_df['Alignment']=='good'][ stats_df['Total']>6])
# Out:
# C:\Users\polluxs\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
=
# Out:
# Int64Index([  0,   1,   2,   3,   6,   9,  10,  12,  14,  19,
#             ...
#             598, 599, 600, 602, 603, 604, 606, 607, 608, 609],
#            dtype='int64', length=299)

# %%
stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 611 entries, 0 to 610
# Data columns (total 9 columns):
# Name            611 non-null object
# Alignment       608 non-null object
# Intelligence    611 non-null int64
# Strength        611 non-null int64
# Speed           611 non-null int64
# Durability      611 non-null int64
# Power           611 non-null int64
# Combat          611 non-null int64
# Total           611 non-null int64
# dtypes: int64(7), object(2)
# memory usage: 43.0+ KB

# %%
stats_df[stats_df['Total']>=6]
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0              3-D Man      good            50        31     43          32
# 1               A-Bomb      good            38       100     17          80
# 2           Abe Sapien      good            88        14     35          42
# 3             Abin Sur      good            50        90     53          64
# 4          Abomination       bad            63        80     53          90
# 5              Abraxas       bad            88       100     83          99
# 6          Adam Monroe      good            63        10     12         100
# 9            Agent Bob      good            10         8     13           5
# 10          Agent Zero      good            75        28     38          80
# 11          Air-Walker       bad            50        85    100          85
# 12          Alan Scott      good            63        80     23          90
# ...

# %%
stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 611 entries, 0 to 610
# Data columns (total 9 columns):
# Name            611 non-null object
# Alignment       608 non-null object
# Intelligence    611 non-null int64
# Strength        611 non-null int64
# Speed           611 non-null int64
# Durability      611 non-null int64
# Power           611 non-null int64
# Combat          611 non-null int64
# Total           611 non-null int64
# dtypes: int64(7), object(2)
# memory usage: 43.0+ KB

# %%
marvel_DC_char_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39648 entries, 0 to 39647
# Data columns (total 12 columns):
# ID                 39648 non-null int64
# Name               39648 non-null object
# Identity           30095 non-null object
# Alignment          33423 non-null object
# EyeColor           16486 non-null object
# HairColor          28846 non-null object
# Gender             37815 non-null object
# Status             39639 non-null object
# Appearances        37101 non-null float64
# FirstAppearance    37949 non-null object
# Year               37949 non-null float64
# Universe           39648 non-null object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 3.6+ MB
